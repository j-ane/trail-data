# %%
import pandas as pd
df = pd.read_json('Alabama.json')
df.head()
# Out:
#          ID                              _geoloc  \
# 0  10234690  {'lat': 34.97677, 'lng': -86.08019}
# 1  10030503  {'lat': 33.47097, 'lng': -85.80614}
# 2  10034876  {'lat': 33.45964, 'lng': -85.87405}
# 3  10019678  {'lat': 34.73412, 'lng': -86.72833}
# 4  10258164  {'lat': 34.23526, 'lng': -87.43408}
#
#                                           activities  \
# 0  [birding, camping, hiking, nature-trips, trail...
# 1                     [backpacking, camping, hiking]
# 2  [backpacking, birding, camping, fishing, hikin...
# 3                   [hiking, trail-running, walking]
# 4                                          [walking]
#
#                                       activity_names     area_id  \
# 0  [Bird Watching, Camping, Hiking, Nature Trips,...         NaN
# 1                     [Backpacking, Camping, Hiking]  10107306.0
# 2  [Backpacking, Bird Watching, Camping, Fishing,...  10151269.0
# 3                         [Hiking, Running, Walking]  10161530.0
# ...

# %%
# Out:
#          ID                              _geoloc  \
# 0  10234690  {'lat': 34.97677, 'lng': -86.08019}
# 1  10030503  {'lat': 33.47097, 'lng': -85.80614}
# 2  10034876  {'lat': 33.45964, 'lng': -85.87405}
# 3  10019678  {'lat': 34.73412, 'lng': -86.72833}
# 4  10258164  {'lat': 34.23526, 'lng': -87.43408}
#
#                                           activities  \
# 0  [birding, camping, hiking, nature-trips, trail...
# 1                     [backpacking, camping, hiking]
# 2  [backpacking, birding, camping, fishing, hikin...
# 3                   [hiking, trail-running, walking]
# 4                                          [walking]
#
#                                       activity_names     area_id  \
# 0  [Bird Watching, Camping, Hiking, Nature Trips,...         NaN
# 1                     [Backpacking, Camping, Hiking]  10107306.0
# 2  [Backpacking, Bird Watching, Camping, Fishing,...  10151269.0
# 3                         [Hiking, Running, Walking]  10161530.0
# ...
